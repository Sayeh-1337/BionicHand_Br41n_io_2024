# %%
import json
import shutil
import logging
import importlib
import numpy as np
import pandas as pd
import tensorflow as tf

from utils import *
from models import *
from datasets import set_dataset_dir
from custom_train_objects.generators import EEGGrouperGenerator
from experiments import data_utils, model_utils, scenarios_utils, scenarios

logger = logging.getLogger(__name__)

# files have to be in data/Large_Scale_BCI/*
set_dataset_dir('data')
set_display_options()

for module in (model_utils, data_utils, scenarios_utils, scenarios): importlib.reload(module)

# this model is based on embeddings
name = 'eegtcnet_fit_ds-largescalebci_ge2e_metric-euclidian_nlab-5_nut-24_dim-32_ea_norm-no_winoff-0_winlen-250_passive_subj-B_scenario-1'

# This model is based on classification score for each label
#name = 'eegtcnet_fit_ds-largescalebci_ea_norm-no_winoff-0_winlen-250_passive_subj-B_scenario-1'

name = scenarios_utils.format_model_name(name, subject = range(1, 10))

config = scenarios._get_scenario_config(name, gpu = 0)
scenarios_utils.validate_scenario_config(config)

scenarios._setup_gpu_config(config)

random_state = None if not isinstance(config['run'], int) else config['run']
if random_state is not None:
    np.random.seed(random_state)
    tf.random.set_seed(random_state)

train, valid, test, config = data_utils.get_experimental_data(
    config, random_state = random_state
)
# to remove data that are not long enough for the model as it requires fixed length input data
train = train[train['time'] == 250]
valid = valid[valid['time'] == 250]
test = test[test['time'] == 250]

#scenarios_utils.validate_scenario_data(config, train = train, valid = valid, test = test)
model, config = model_utils.build_model(name, config)

filepath =  '{}/best_weights.keras'.format(model.save_dir)
if model.epochs == 0 and not os.path.exists(filepath) and not config['skip_new']:
    config['train_config']['test_size'] = 0
    scenarios.fit_model(model, config, train = train, valid = valid, filepath = filepath)
# load the best model weights
model.load_weights(filepath)
# evaluate the model on the test subset
# metrics = scenarios.evaluate_model(
#     model = model, data = test, config = config, filepath = filepath, samples = train, overwrite = False
# )

#config['metrics'] = scenarios._get_metrics(name, config = config, metrics = metrics)

#print(json.dumps(to_json(config), indent = 4))
# Out:
# Error while setting visible devices : list index out of range
# Loading dataset largescalebci...
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-151110-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-151110-5St-SGLHand.fif, 22 x 724600 (3623.0 s), ~121.6 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'pinkie finger (IM)', 'index finger (IM)', 'middle finger (IM)', 'thumb finger (IM)', 'ring finger (IM)'}
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-160309-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-160309-5St-SGLHand.fif, 22 x 715588 (3577.9 s), ~120.1 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)'}
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-160311-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-160311-5St-SGLHand.fif, 22 x 718265 (3591.3 s), ~120.6 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'break', 'thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)'}
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-160316-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-160316-5St-SGLHand.fif, 22 x 717984 (3589.9 s), ~120.5 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'break', 'thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)'}
#
# ====================
# Dataset information
# ====================
#
# General :
#   - sampling rate  : 200
#   - # EEG channels : 22
#   - Labels (n = 8) : ['relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'passive', 'break', ...]
#
# # Samples :
#   - Train size    : 4900
#   - Valid size    : 1225
#   - Test size     : 1532
#   - valid == test : False
#
# Subjects :
#   - # subject(s) in train : 1
#   - # subject(s) in valid : 1
#   - # subject(s) in test  : 1
#   - # subject(s) in train and valid : 1
#   - # subject(s) in train and test  : 1
#
# Sessions :
#   - # session(s) in train : 4
#   - # session(s) in valid : 4
#   - # session(s) in test  : 4
#   - # session(s) in train and valid : 4
#   - # session(s) in train and test  : 4
#
# Model restoration...
# Model model has not been restored due to an exception : Requested the deserialization of a Lambda layer with a Python `lambda` inside it. This carries a potential risk of arbitrary code execution and thus it is disallowed by default. If you trust the source of the saved model, you can pass `safe_mode=False` to the loading function in order to allow Lambda layer loading.
# Initializing model with kwargs : {'model': {'architecture_name': 'eegtcnet', 'multi_subjects': False, 'labels': ['Finger 1 (thumb)', 'Finger 2 (index)', 'Finger 3 (middle)', 'Finger 4', 'Finger 5 (pinkie)', 'passive'], 'output_dim': 32, 'final_activation': None, 'input_shape': (250, 22)}}
# Initializing submodel : `model` !
# Optimizer 'model_optimizer' initilized successfully !
# [WARNING] Some layers have not bene restored from the checkpoint ! Run `model.load_checkpoint().assert_consumed()` to check if it is a critical error or not
# Model eegtcnet_fit_ds-largescalebci_ge2e_metric-euclidian_nlab-5_nut-24_dim-32_ea_norm-no_winoff-0_winlen-250_passive_subj-B_scenario-1 initialized successfully !
#
# ========== eegtcnet_fit_ds-largescalebci_ge2e_metric-euclidian_nlab-5_nut-24_dim-32_ea_norm-no_winoff-0_winlen-250_passive_subj-B_scenario-1 ==========
# Sub model model
# - Inputs 	: (None, 250, 22, 1)
# - Outputs 	: (None, 32)
# - Number of layers 	: 37
# - Number of parameters 	: 0.005 Millions
# - Optimizer 	: {'name': 'Adam', 'weight_decay': None, 'clipnorm': None, 'global_clipnorm': None, 'clipvalue': None, 'use_ema': False, 'ema_momentum': 0.99, 'ema_overwrite_frequency': None, 'jit_compile': False, 'is_legacy_optimizer': False, 'learning_rate': 0.0007290001, 'beta_1': 0.9, 'beta_2': 0.999, 'epsilon': 1e-07, 'amsgrad': False}
# - Loss 	 : {'reduction': 'auto', 'name': 'ge2e_loss', 'mode': 'softmax', 'init_w': -1.7834996, 'init_b': 0.00059977995, 'distance_metric': 'euclidian'}
# - Metrics	 : [{'name': 'accuracy', 'dtype': 'float32', 'mode': 'softmax', 'distance_metric': 'euclidian'}]
#
# Already trained on 123 epochs (7011 steps)

# %%
from datasets import get_dataset

encoder = model if not hasattr(model, 'encoder') else model.encoder
# load the complete dataset of raw data and remove the 1st relaxation phase + the index finger
real_data = get_dataset('large_scale_bci', subset = '5F', subject = 'B', keep_passive = True, keep_artifact = True).iloc[1:]
print(real_data)
#_labels = ('Finger 1 (thumb)', 'Finger 2 (index)', 'Finger 3 (middle)', 'Finger 4', 'Finger 5 (pinkie)')
_labels = ('thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)', 'pinky finger (IM)')
_labels = None
real_data['label'] = real_data['event_id']
if _labels:
    real_data = real_data[real_data['label'].apply(lambda l: any(lab in l for lab in _labels))]

# we take 25% of the data as reference points
n = len(real_data) // 4
calibration_data, real_data = real_data.iloc[:n], real_data.iloc[n:]

#concatenate all the trials in a single long EEG recording
real_eeg = np.concatenate(list(real_data['eeg'].values), axis = 1)
print(real_eeg.shape)

#pre-processing
calibration_data['eeg'] = calibration_data['eeg'].apply(lambda eeg: eeg[:, :model.max_input_length])
calibration_data = calibration_data[calibration_data['eeg'].apply(lambda eeg: eeg.shape[1] == 250)]
# we create reference embeddings along with their ID (known thanks to calibration time)
calibration_data = train
train_samples = model.build_samples(calibration_data, model = encoder)

print('Train samples : {}'.format(
    {k : v.shape for k, v in train_samples.items()}
))

real_data.head()
# Out:
# Loading dataset largescalebci...
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-151110-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-151110-5St-SGLHand.fif, 22 x 724600 (3623.0 s), ~121.6 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'pinkie finger (IM)', 'index finger (IM)', 'middle finger (IM)', 'thumb finger (IM)', 'ring finger (IM)'}
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-160309-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-160309-5St-SGLHand.fif, 22 x 715588 (3577.9 s), ~120.1 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)'}
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-160311-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-160311-5St-SGLHand.fif, 22 x 718265 (3591.3 s), ~120.6 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'break', 'thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)'}
# c:\Data\hackaton_2024\utils\eeg_utils\eeg_io.py:311: RuntimeWarning: This filename (data/Large_scale_BCI\5F-SubjectB-160316-5St-SGLHand.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   data   = getattr(mne.io, io_method)(filename, preload = add_signal, verbose = False) if isinstance(filename, str) else filename
# The file <Raw | 5F-SubjectB-160316-5St-SGLHand.fif, 22 x 717984 (3589.9 s), ~120.5 MB, data loaded> does not have any subject information !
# Unknown events detected !
#   Mapping : {0: 'passive', 1: 'Finger 1 (thumb)', 2: 'Finger 2 (index)', 3: 'Finger 3 (middle)', 4: 'Finger 4 (ring)', 5: 'Finger 5 (pinkie)', 90: 'passive', 91: 'passive', 92: 'experiment end', 99: 'passive'}
#   Unknown : {'relaxation', 'pinkie finger (IM)', 'index finger (IM)', 'break', 'thumb finger (IM)', 'middle finger (IM)', 'ring finger (IM)'}
#                 event_id   start     end  time          event_name   age   sex meas_date  rate  \
# 1      thumb finger (IM)   37376   37641   265   thumb finger (IM)  None  None    151110   200
# 2                passive   37641   38078   437             passive  None  None    151110   200
# 3      index finger (IM)   38078   38338   260   index finger (IM)  None  None    151110   200
# 4                passive   38338   38699   361             passive  None  None    151110   200
# 5       ring finger (IM)   38699   38958   259    ring finger (IM)  None  None    151110   200
# ...                  ...     ...     ...   ...                 ...   ...   ...       ...   ...
# 7652  middle finger (IM)  716311  716573   262  middle finger (IM)  None  None    160316   200
# 7653             passive  716573  716998   425             passive  None  None    160316   200
# 7654  pinkie finger (IM)  716998  717257   259  pinkie finger (IM)  None  None    160316   200
# 7655             passive  717257  717725   468             passive  None  None    160316   200
# 7656  pinkie finger (IM)  717725  717983   258  pinkie finger (IM)  None  None    160316   200
#
#                                                channels                                                eeg  \
# 1     [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-1.197e-05, -1.193e-05, -1.411e-05, -1.467e-...
# 2     [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[1.043e-05, 8.99e-06, 8.6e-06, 6.38e-06, 5.22...
# 3     [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-8.99e-06, -8.87e-06, -8.93e-06, -1.087e-05,...
# 4     [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[6.9e-07, 1.34e-06, 1.5e-07, -1.2e-07, -8.9e-...
# 5     [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[1.26e-06, 2.02e-06, 7.7e-07, -1e-08, 8e-07, ...
# ...                                                 ...                                                ...
# 7652  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[4.65e-06, -2.71e-06, -6.95e-06, 1e-08, 8.64e...
# 7653  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-1.007e-05, -8.87e-06, -8.69e-06, -8.76e-06,...
# 7654  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-9.8e-07, -1.75e-06, -5.62e-06, -3.07e-06, -...
# 7655  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-3.88e-06, -4.19e-06, -7.4e-07, 1.64e-06, -2...
# 7656  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-1.95e-06, 6.74e-06, 5.29e-06, -5.41e-06, -8...
#
#                      id task    device               label  n_channels     dataset_name                   session
# 1     Large scale BCI-B   5f  EEG 1200   thumb finger (IM)          22  Large scale BCI  Large scale BCI-B-151110
# 2     Large scale BCI-B   5f  EEG 1200             passive          22  Large scale BCI  Large scale BCI-B-151110
# 3     Large scale BCI-B   5f  EEG 1200   index finger (IM)          22  Large scale BCI  Large scale BCI-B-151110
# 4     Large scale BCI-B   5f  EEG 1200             passive          22  Large scale BCI  Large scale BCI-B-151110
# 5     Large scale BCI-B   5f  EEG 1200    ring finger (IM)          22  Large scale BCI  Large scale BCI-B-151110
# ...                 ...  ...       ...                 ...         ...              ...                       ...
# 7652  Large scale BCI-B   5f  EEG 1200  middle finger (IM)          22  Large scale BCI  Large scale BCI-B-160316
# 7653  Large scale BCI-B   5f  EEG 1200             passive          22  Large scale BCI  Large scale BCI-B-160316
# 7654  Large scale BCI-B   5f  EEG 1200  pinkie finger (IM)          22  Large scale BCI  Large scale BCI-B-160316
# 7655  Large scale BCI-B   5f  EEG 1200             passive          22  Large scale BCI  Large scale BCI-B-160316
# 7656  Large scale BCI-B   5f  EEG 1200  pinkie finger (IM)          22  Large scale BCI  Large scale BCI-B-160316
#
# [7656 rows x 18 columns]
# (22, 2154325)
# Train samples : {'ids': (4888,), 'channels': (4888, 22), 'embeddings': TensorShape([4888, 32]), 'labels': TensorShape([4888])}
#                event_id   start     end   time         event_name   age   sex meas_date  rate  \
# 1915  thumb finger (IM)  722076  722338    262  thumb finger (IM)  None  None    151110   200
# 1916            passive  722338  724600   2262            passive  None  None    151110   200
# 1917            passive       0   30083  30083            passive  None  None    160309   200
# 1918         relaxation   30083   30289    206         relaxation  None  None    160309   200
# 1919            passive   30288   31091    803            passive  None  None    160309   200
#
#                                                channels                                                eeg  \
# 1915  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-5e-08, -2.7e-06, -1.78e-06, -1.04e-06, 1.6e...
# 1916  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[1.62e-06, -1.08e-06, -4.23e-06, -3.5e-06, 1....
# 1917  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[1.270139e-07, -1.2701786e-07, 1.270222e-07, ...
# 1918  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[5.8822214e-05, 5.8698064e-05, 6.5396336e-05,...
# 1919  [Fp1, Fp2, F3, F4, C3, C4, P3, P4, O1, O2, A1,...  [[-4.4697713e-06, -4.316596e-06, -3.3530757e-0...
#
#                      id task    device              label  n_channels     dataset_name                   session
# 1915  Large scale BCI-B   5f  EEG 1200  thumb finger (IM)          22  Large scale BCI  Large scale BCI-B-151110
# 1916  Large scale BCI-B   5f  EEG 1200            passive          22  Large scale BCI  Large scale BCI-B-151110
# 1917  Large scale BCI-B   5f  EEG 1200            passive          22  Large scale BCI  Large scale BCI-B-160309
# 1918  Large scale BCI-B   5f  EEG 1200         relaxation          22  Large scale BCI  Large scale BCI-B-160309
# 1919  Large scale BCI-B   5f  EEG 1200            passive          22  Large scale BCI  Large scale BCI-B-160309

# %%
reference_ids, reference_embeddings = train_samples['labels'], train_samples['embeddings']

subj_id = real_data.iloc[0]['id']
rate = real_data.iloc[0]['rate']
channels = real_data.iloc[0]['channels']
window_len = int(1. * rate)

labels = np.unique(reference_ids)

for i in range(100):
    data = real_eeg[:, i * window_len : i * window_len + model.max_input_length]
    embedded = encoder(model.get_input({
        'eeg' : data, 'rate' : rate, 'channels' : channels, 'id' : subj_id
    })[None], training = False)
    ids, scores = knn(
        embedded, reference_embeddings, ids = reference_ids, distance_metric = 'euclidian', k = 50, weighted = False, return_scores = True
    )
    scores = scores[0]
    print('The prediction is index {} ({}) with probabilities : {}'.format(
        np.argmax(scores), ids[np.argmax(scores)].numpy().decode(), scores
    ))
    print(convert_to_str(ids), tf.one_hot(np.argmax(scores), 5).numpy())
# Out:
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 4. 16.  0.  2.  0. 27.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 3 (pinkie finger (IM)) with probabilities : [ 6.  8. 10. 15.  7.  4.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 1. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2.  8. 17.  1.  0. 22.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 41.  5.  3.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 1.  6. 23.  5.  0. 15.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2. 11.  2.  2.  0. 32.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 3.  7. 20.  4.  0. 16.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 1.  3. 39.  4.  0.  3.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 49.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 3.  2. 35.  7.  2.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 1.  4. 24.  2.  1. 18.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 49.  0.  0.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 2.  8. 19.  5.  0. 16.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 48.  1.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2. 10.  5.  2.  0. 31.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 49.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 2.  5. 31.  2.  0. 10.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 1.  3. 29.  2.  1. 14.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 7. 13.  0.  1. 11. 18.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 1.  2. 33.  3.  0. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 4 (ring finger (IM)) with probabilities : [ 8.  3.  2. 10. 19.  7.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 49.  0.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 49.  0.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 3.  9.  2.  1.  0. 34.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 2.  1. 42.  4.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 44.  2.  0.  3.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 3 (pinkie finger (IM)) with probabilities : [ 4.  2.  0. 34.  8.  2.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 1. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 6. 18.  0.  3.  1. 22.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  2. 40.  2.  0.  6.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 1.  5. 32.  4.  0.  8.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 4. 11.  5.  2.  3. 25.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 4.  7. 14.  5.  9. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 5. 16.  1.  5.  3. 19.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 4 (ring finger (IM)) with probabilities : [11.  6.  4.  7. 17.  5.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# The prediction is index 4 (ring finger (IM)) with probabilities : [10.  9.  2.  6. 16.  7.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# The prediction is index 1 (index finger (IM)) with probabilities : [15. 16.  0.  6.  2. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 1. 0. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 4. 12.  3.  4.  1. 25.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 40.  4.  5.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 4 (ring finger (IM)) with probabilities : [ 8.  2.  0.  9. 25.  5.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# The prediction is index 0 (middle finger (IM)) with probabilities : [13.  8.  2. 10.  9.  8.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [1. 0. 0. 0. 0.]
# The prediction is index 4 (ring finger (IM)) with probabilities : [12.  8.  3.  7. 15.  5.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 2.  1. 45.  0.  0.  2.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 0. 15.  0.  2.  1. 32.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 2.  1. 41.  1.  0.  5.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 5.  3. 21.  2.  5. 14.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2.  6. 18.  1.  0. 23.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  3. 35.  3.  0.  9.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 3. 11. 10.  5.  2. 19.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2.  9.  2.  3.  0. 33.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 48.  0.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 3 (pinkie finger (IM)) with probabilities : [ 4.  2.  0. 28. 14.  2.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 1. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 2.  2. 31.  2.  2. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]

# %%
import requests
import json
import time

reference_ids, reference_embeddings = train_samples['labels'], train_samples['embeddings']

subj_id = real_data.iloc[0]['id']
rate = real_data.iloc[0]['rate']
channels = real_data.iloc[0]['channels']
window_len = int(1. * rate)

labels = np.unique(reference_ids)

for i in range(100):
    data = real_eeg[:, i * window_len : i * window_len + model.max_input_length]
    embedded = encoder(model.get_input({
        'eeg' : data, 'rate' : rate, 'channels' : channels, 'id' : subj_id
    })[None], training = False)
    ids, scores = knn(
        embedded, reference_embeddings, ids = reference_ids, distance_metric = 'euclidian', k = 50, weighted = False, return_scores = True
    )
    scores = scores[0]
    print('The prediction is index {} ({}) with probabilities : {}'.format(
        np.argmax(scores), ids[np.argmax(scores)].numpy().decode(), scores
    ))
    print(convert_to_str(ids), tf.one_hot(np.argmax(scores), 5).numpy())
    # API endpoint 
    url= "http://localhost:8180/api/control"

    #JSON payload

    payload = {
        "control": to_json(tf.one_hot(np.argmax(scores), 5).numpy().astype(int))
    }

    # Convert payload to JSON string
    json_payload = json.dumps(payload)

    #Set headers
    headers = {
        "Content-Type": "application/json"
    }   

    response = requests.post(url, headers=headers, data=json_payload)
    
    # Check the response status code
    if response.status_code == 200:
        print("POST request successful!")
    else:
        print("POST request failed with status code:", response.status_code)
    
    #time.sleep(0.5)
# Out:
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 4. 16.  0.  2.  0. 27.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 3 (pinkie finger (IM)) with probabilities : [ 6.  8. 10. 15.  7.  4.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 1. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2.  8. 17.  1.  0. 22.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 41.  5.  3.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 1.  6. 23.  5.  0. 15.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2. 11.  2.  2.  0. 32.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 3.  7. 20.  4.  0. 16.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 1.  3. 39.  4.  0.  3.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 49.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 3.  2. 35.  7.  2.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 1.  4. 24.  2.  1. 18.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 49.  0.  0.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 2.  8. 19.  5.  0. 16.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 48.  1.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2. 10.  5.  2.  0. 31.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 49.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 2.  5. 31.  2.  0. 10.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 1.  3. 29.  2.  1. 14.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 7. 13.  0.  1. 11. 18.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 1.  2. 33.  3.  0. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 4 (ring finger (IM)) with probabilities : [ 8.  3.  2. 10. 19.  7.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 49.  0.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 49.  0.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 3.  9.  2.  1.  0. 34.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 2.  1. 42.  4.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 44.  2.  0.  3.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 3 (pinkie finger (IM)) with probabilities : [ 4.  2.  0. 34.  8.  2.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 1. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 6. 18.  0.  3.  1. 22.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  2. 40.  2.  0.  6.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 1.  5. 32.  4.  0.  8.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 4. 11.  5.  2.  3. 25.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 4.  7. 14.  5.  9. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 5. 16.  1.  5.  3. 19.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 4 (ring finger (IM)) with probabilities : [11.  6.  4.  7. 17.  5.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# POST request successful!
# The prediction is index 4 (ring finger (IM)) with probabilities : [10.  9.  2.  6. 16.  7.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# POST request successful!
# The prediction is index 1 (index finger (IM)) with probabilities : [15. 16.  0.  6.  2. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 1. 0. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 4. 12.  3.  4.  1. 25.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 40.  4.  5.  1.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 4 (ring finger (IM)) with probabilities : [ 8.  2.  0.  9. 25.  5.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# POST request successful!
# The prediction is index 0 (middle finger (IM)) with probabilities : [13.  8.  2. 10.  9.  8.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [1. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 4 (ring finger (IM)) with probabilities : [12.  8.  3.  7. 15.  5.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 1.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 2.  1. 45.  0.  0.  2.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 0. 15.  0.  2.  1. 32.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 2.  1. 41.  1.  0.  5.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 5.  3. 21.  2.  5. 14.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2.  6. 18.  1.  0. 23.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  3. 35.  3.  0.  9.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 3. 11. 10.  5.  2. 19.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 5 (thumb finger (IM)) with probabilities : [ 2.  9.  2.  3.  0. 33.  1.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  1. 48.  0.  1.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 3 (pinkie finger (IM)) with probabilities : [ 4.  2.  0. 28. 14.  2.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 0. 1. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 2.  2. 31.  2.  2. 11.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
# The prediction is index 2 (passive) with probabilities : [ 0.  0. 50.  0.  0.  0.  0.]
# ['middle finger (IM)', 'index finger (IM)', 'passive', 'pinkie finger (IM)', 'ring finger (IM)', 'thumb finger (IM)', 'break'] [0. 0. 1. 0. 0.]
# POST request successful!
